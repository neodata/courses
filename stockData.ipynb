# %%
import yfinance as yf
import pandas as pd
import json


ap = yf.Ticker("AMD")

# Get stock info
ap.info

ap.history(period="ytd")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[47], line 9
#       6 ap = yf.Ticker("AMD")
#       8 # Get stock info
# ----> 9 ap.info
#      11 ap.history(period="ytd")
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\ticker.py:159, in Ticker.info(self)
#     157 @property
#     158 def info(self) -> dict:
# --> 159     return self.get_info()
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\base.py:229, in TickerBase.get_info(self, proxy)
#     227 def get_info(self, proxy=None) -> dict:
#     228     self._quote.proxy = proxy or self.proxy
# --> 229     data = self._quote.info
#     230     return data
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\scrapers\quote.py:508, in Quote.info(self)
#     505 @property
#     506 def info(self) -> dict:
#     507     if self._info is None:
# --> 508         self._fetch_info(self.proxy)
#     509         self._fetch_complementary(self.proxy)
#     511     return self._info
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\scrapers\quote.py:598, in Quote._fetch_info(self, proxy)
#     596 self._already_fetched = True
#     597 modules = ['financialData', 'quoteType', 'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 598 result = self._fetch(proxy, modules=modules)
#     599 if result is None:
#     600     self._info = {}
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\scrapers\quote.py:587, in Quote._fetch(self, proxy, modules)
#     585 params_dict = {"modules": modules, "corsDomain": "finance.yahoo.com", "formatted": "false", "symbol": self._symbol}
#     586 try:
# --> 587     result = self._data.get_raw_json(_QUOTE_SUMMARY_URL_ + f"/{self._symbol}", user_agent_headers=self._data.user_agent_headers, params=params_dict, proxy=proxy)
#     588 except requests.exceptions.HTTPError as e:
#     589     utils.get_yf_logger().error(str(e))
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\data.py:410, in YfData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     408 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     409     utils.get_yf_logger().debug(f'get_raw_json(): {url}')
# --> 410     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#     411     response.raise_for_status()
#     412     return response.json()
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\data.py:333, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     331 @utils.log_indent_decorator
#     332 def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 333     return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\yfinance\data.py:378, in YfData._make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     375 if body:
#     376     request_args['json'] = body
# --> 378 response = request_method(**request_args)
#     379 utils.get_yf_logger().debug(f'response code={response.status_code}')
#     380 if response.status_code >= 400:
#     381     # Retry with other cookie strategy
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\LENOVO\Documents\Python\courses\.venv\Lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
apple.history(period="1d")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-11-04 00:00:00-05:00  220.990005  222.789993  219.710007  222.009995
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-11-04 00:00:00-05:00  44903300        0.0           0.0

# %%
# Extracting Share Price

apple.info["currentPrice"]
# Out:
# 222.01

# %%
# Get historical Data

apple_share_price_data = apple.history()
apple_share_price_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-07 00:00:00-04:00  224.500000  225.690002  221.330002  221.690002
# 2024-10-08 00:00:00-04:00  224.300003  225.979996  223.250000  225.770004
# 2024-10-09 00:00:00-04:00  225.229996  229.750000  224.830002  229.539993
# 2024-10-10 00:00:00-04:00  227.779999  229.500000  227.169998  229.039993
# 2024-10-11 00:00:00-04:00  229.300003  229.410004  227.339996  227.550003
# 2024-10-14 00:00:00-04:00  228.699997  231.729996  228.600006  231.300003
# 2024-10-15 00:00:00-04:00  233.610001  237.490005  232.369995  233.850006
# 2024-10-16 00:00:00-04:00  231.600006  232.119995  229.839996  231.779999
# 2024-10-17 00:00:00-04:00  233.429993  233.850006  230.520004  232.149994
# 2024-10-18 00:00:00-04:00  236.179993  236.179993  234.009995  235.000000
# 2024-10-21 00:00:00-04:00  234.449997  236.850006  234.449997  236.479996
# 2024-10-22 00:00:00-04:00  233.889999  236.220001  232.600006  235.860001
# 2024-10-23 00:00:00-04:00  234.080002  235.139999  227.759995  230.759995
# 2024-10-24 00:00:00-04:00  229.979996  230.820007  228.410004  230.570007
# 2024-10-25 00:00:00-04:00  229.740005  233.220001  229.570007  231.410004
# 2024-10-28 00:00:00-04:00  233.320007  234.729996  232.550003  233.399994
# 2024-10-29 00:00:00-04:00  233.100006  234.330002  232.320007  233.669998
# 2024-10-30 00:00:00-04:00  232.610001  233.470001  229.550003  230.100006
